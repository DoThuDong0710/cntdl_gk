# %%
import requests

# %%
url = "http://localhost:3131"

# %%
response = requests.post(f"{url}/search", json = {"query": "Hội nghị cấp khoa?"})

# %%
response.json()
# Out:
# {'query': 'Hội nghị cấp khoa?',
#  'result': {'id': '04bcfe96-95a3-44d6-b9c1-0f741790e7fa',
#   'payload': {'content': 'Khóa học lập trình web của công ty LIKELION tại khoa CNTT\xa0đã kết thúc trong niềm hân hoan trọn vẹn. Khóa học có sự tham gia của các bạn sinh viên thuộc bộ môn Kỹ Thuật Phần Mềm\xa0 khoa CNTT và\xa0cả thầy cô đến từ khoa Điện.\nSau 8 buổi học, khoá học\xa0không chỉ cho và nhận kiến thức mà còn là những kỉ niệm khó quên. Các giảng viên đến từ Hàn Quốc của LIKELION không chỉ có kiến thức chuyên môn mà còn là sự tận tâm, nhiệt huyết để các bài tập và nút thắt dù khó đến đâu vẫn có thể tháo gỡ nhanh nhất. Và để tạo nên sự thành công của khóa học không thể không nhắc đến thầy cô và các bạn sinh viên của khoa CNTT đều rất tuyệt vời, dù lịch học và lịch công tác dày đặc nhưng không một ai bỏ lớp, thật tuyệt vời.\n\n',
#    'date': '02-02-2021',
#    'embedding': [0.00978438276797533,
#     -0.01410610694438219,
#     -0.0523546002805233,
#     -0.03143251687288284,
# ...
